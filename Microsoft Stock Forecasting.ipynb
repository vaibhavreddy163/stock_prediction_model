# %% [markdown]
# <a href="https://colab.research.google.com/github/shifavoila/Stock-Prediction/blob/main/Microsoft_Stock_Forecasting_using_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060396
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062553
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063632
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062014
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060936
# ...          ...         ...         ...         ...         ...         ...
# 9476  2023-10-18  332.489990  335.589996  328.299988  330.109985  330.109985
# 9477  2023-10-19  332.149994  336.880005  330.910004  331.320007  331.320007
# 9478  2023-10-20  331.720001  331.920013  325.450012  326.670013  326.670013
# 9479  2023-10-23  325.470001  332.730011  324.390015  329.320007  329.320007
# 9480  2023-10-24  331.299988  331.839996  327.600006  330.529999  330.529999
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9476    23153600
# 9477    25052100
# 9478    25012600
# 9479    24374700
# 9480    30444300
#
# [9481 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9476  2023-10-18  330.109985
# 9477  2023-10-19  331.320007
# 9478  2023-10-20  326.670013
# 9479  2023-10-23  329.320007
# 9480  2023-10-24  330.529999
#
# [9481 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9476    2023-10-18
# 9477    2023-10-19
# 9478    2023-10-20
# 9479    2023-10-23
# 9480    2023-10-24
# Name: Date, Length: 9481, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9476  2023-10-18  330.109985
# 9477  2023-10-19  331.320007
# 9478  2023-10-20  326.670013
# 9479  2023-10-23  329.320007
# 9480  2023-10-24  330.529999
#
# [9481 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-6-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9476   2023-10-18
# 9477   2023-10-19
# 9478   2023-10-20
# 9479   2023-10-23
# 9480   2023-10-24
# Name: Date, Length: 9481, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-10-18  330.109985
# 2023-10-19  331.320007
# 2023-10-20  326.670013
# 2023-10-23  329.320007
# 2023-10-24  330.529999
#
# [9481 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 4s 155ms/step - loss: 84692.0781 - mean_absolute_error: 289.2792 - val_loss: 92358.2031 - val_mean_absolute_error: 303.8177
# Epoch 2/100
# 7/7 [==============================] - 0s 14ms/step - loss: 84432.9688 - mean_absolute_error: 288.8284 - val_loss: 92112.8203 - val_mean_absolute_error: 303.4137
# Epoch 3/100
# 7/7 [==============================] - 0s 12ms/step - loss: 84178.3359 - mean_absolute_error: 288.3888 - val_loss: 91819.5781 - val_mean_absolute_error: 302.9300
# Epoch 4/100
# 7/7 [==============================] - 0s 12ms/step - loss: 83872.5859 - mean_absolute_error: 287.8569 - val_loss: 91439.6875 - val_mean_absolute_error: 302.3023
# Epoch 5/100
# 7/7 [==============================] - 0s 16ms/step - loss: 83475.2031 - mean_absolute_error: 287.1673 - val_loss: 90974.1875 - val_mean_absolute_error: 301.5314
# Epoch 6/100
# 7/7 [==============================] - 0s 15ms/step - loss: 83020.8672 - mean_absolute_error: 286.3743 - val_loss: 90446.3125 - val_mean_absolute_error: 300.6548
# Epoch 7/100
# 7/7 [==============================] - 0s 12ms/step - loss: 82382.5078 - mean_absolute_error: 285.2544 - val_loss: 89496.4375 - val_mean_absolute_error: 299.0708
# Epoch 8/100
# 7/7 [==============================] - 0s 10ms/step - loss: 81361.5703 - mean_absolute_error: 283.4589 - val_loss: 88372.0000 - val_mean_absolute_error: 297.1852
# Epoch 9/100
# 7/7 [==============================] - 0s 8ms/step - loss: 80313.7344 - mean_absolute_error: 281.6100 - val_loss: 87154.3125 - val_mean_absolute_error: 295.1293
# Epoch 10/100
# 7/7 [==============================] - 0s 8ms/step - loss: 79097.8047 - mean_absolute_error: 279.4383 - val_loss: 85830.7578 - val_mean_absolute_error: 292.8784
# Epoch 11/100
# 7/7 [==============================] - 0s 8ms/step - loss: 77766.0312 - mean_absolute_error: 277.0442 - val_loss: 84282.6172 - val_mean_absolute_error: 290.2234
# Epoch 12/100
# 7/7 [==============================] - 0s 8ms/step - loss: 76250.4141 - mean_absolute_error: 274.2985 - val_loss: 82605.6953 - val_mean_absolute_error: 287.3199
# Epoch 13/100
# 7/7 [==============================] - 0s 9ms/step - loss: 74579.8984 - mean_absolute_error: 271.2343 - val_loss: 80625.2422 - val_mean_absolute_error: 283.8525
# Epoch 14/100
# 7/7 [==============================] - 0s 8ms/step - loss: 72553.1094 - mean_absolute_error: 267.4676 - val_loss: 78250.8828 - val_mean_absolute_error: 279.6388
# Epoch 15/100
# 7/7 [==============================] - 0s 8ms/step - loss: 70144.4844 - mean_absolute_error: 262.9258 - val_loss: 75465.2812 - val_mean_absolute_error: 274.6130
# Epoch 16/100
# 7/7 [==============================] - 0s 8ms/step - loss: 67488.9375 - mean_absolute_error: 257.8157 - val_loss: 72613.7812 - val_mean_absolute_error: 269.3711
# Epoch 17/100
# 7/7 [==============================] - 0s 9ms/step - loss: 64713.8555 - mean_absolute_error: 252.3810 - val_loss: 69519.2188 - val_mean_absolute_error: 263.5645
# Epoch 18/100
# 7/7 [==============================] - 0s 8ms/step - loss: 61687.9141 - mean_absolute_error: 246.3237 - val_loss: 66144.3672 - val_mean_absolute_error: 257.0824
# Epoch 19/100
# 7/7 [==============================] - 0s 9ms/step - loss: 58341.4727 - mean_absolute_error: 239.4142 - val_loss: 62134.8711 - val_mean_absolute_error: 249.1622
# Epoch 20/100
# 7/7 [==============================] - 0s 8ms/step - loss: 54335.0312 - mean_absolute_error: 230.9348 - val_loss: 57771.8867 - val_mean_absolute_error: 240.2475
# Epoch 21/100
# 7/7 [==============================] - 0s 8ms/step - loss: 50132.4844 - mean_absolute_error: 221.5477 - val_loss: 52755.9141 - val_mean_absolute_error: 229.5706
# Epoch 22/100
# 7/7 [==============================] - 0s 8ms/step - loss: 45070.4766 - mean_absolute_error: 209.8304 - val_loss: 47001.7617 - val_mean_absolute_error: 216.6767
# Epoch 23/100
# 7/7 [==============================] - 0s 9ms/step - loss: 39900.6953 - mean_absolute_error: 197.1773 - val_loss: 41796.0586 - val_mean_absolute_error: 204.3113
# Epoch 24/100
# 7/7 [==============================] - 0s 8ms/step - loss: 35089.9141 - mean_absolute_error: 184.5300 - val_loss: 36577.7539 - val_mean_absolute_error: 191.1146
# Epoch 25/100
# 7/7 [==============================] - 0s 8ms/step - loss: 30284.6094 - mean_absolute_error: 171.0385 - val_loss: 31435.4453 - val_mean_absolute_error: 177.1510
# Epoch 26/100
# 7/7 [==============================] - 0s 8ms/step - loss: 25657.8906 - mean_absolute_error: 156.7865 - val_loss: 26459.7969 - val_mean_absolute_error: 162.5018
# Epoch 27/100
# 7/7 [==============================] - 0s 8ms/step - loss: 21175.9805 - mean_absolute_error: 142.0118 - val_loss: 21801.9551 - val_mean_absolute_error: 147.4754
# Epoch 28/100
# 7/7 [==============================] - 0s 8ms/step - loss: 17080.7363 - mean_absolute_error: 126.6338 - val_loss: 17255.8008 - val_mean_absolute_error: 131.1590
# Epoch 29/100
# 7/7 [==============================] - 0s 10ms/step - loss: 13121.0244 - mean_absolute_error: 109.8628 - val_loss: 13210.2471 - val_mean_absolute_error: 114.7052
# Epoch 30/100
# 7/7 [==============================] - 0s 9ms/step - loss: 9854.8984 - mean_absolute_error: 93.8911 - val_loss: 9878.3379 - val_mean_absolute_error: 99.1230
# Epoch 31/100
# 7/7 [==============================] - 0s 9ms/step - loss: 7205.4702 - mean_absolute_error: 78.5434 - val_loss: 7142.5005 - val_mean_absolute_error: 84.1993
# Epoch 32/100
# 7/7 [==============================] - 0s 8ms/step - loss: 5101.5049 - mean_absolute_error: 63.7704 - val_loss: 4738.3413 - val_mean_absolute_error: 68.4444
# Epoch 33/100
# 7/7 [==============================] - 0s 8ms/step - loss: 3223.6174 - mean_absolute_error: 47.4996 - val_loss: 2906.9070 - val_mean_absolute_error: 53.4223
# Epoch 34/100
# 7/7 [==============================] - 0s 8ms/step - loss: 2176.2776 - mean_absolute_error: 37.4672 - val_loss: 1864.3933 - val_mean_absolute_error: 42.5609
# Epoch 35/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1596.9945 - mean_absolute_error: 32.7429 - val_loss: 1194.5101 - val_mean_absolute_error: 33.7867
# Epoch 36/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1283.8113 - mean_absolute_error: 30.2291 - val_loss: 773.5998 - val_mean_absolute_error: 26.8446
# Epoch 37/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1104.1028 - mean_absolute_error: 28.1050 - val_loss: 535.0393 - val_mean_absolute_error: 21.9562
# Epoch 38/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1041.8694 - mean_absolute_error: 27.3207 - val_loss: 384.4008 - val_mean_absolute_error: 18.2054
# Epoch 39/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1013.6772 - mean_absolute_error: 26.9150 - val_loss: 304.0751 - val_mean_absolute_error: 15.8464
# Epoch 40/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1007.4870 - mean_absolute_error: 26.8293 - val_loss: 260.0053 - val_mean_absolute_error: 14.4956
# Epoch 41/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1010.0706 - mean_absolute_error: 26.8751 - val_loss: 245.0180 - val_mean_absolute_error: 14.0074
# Epoch 42/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1012.3474 - mean_absolute_error: 26.8988 - val_loss: 235.2172 - val_mean_absolute_error: 13.6779
# Epoch 43/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1011.2153 - mean_absolute_error: 26.8874 - val_loss: 242.8109 - val_mean_absolute_error: 13.9340
# Epoch 44/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1009.8832 - mean_absolute_error: 26.8621 - val_loss: 257.0834 - val_mean_absolute_error: 14.4018
# Epoch 45/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1010.4823 - mean_absolute_error: 26.8684 - val_loss: 268.2118 - val_mean_absolute_error: 14.7554
# Epoch 46/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1009.9276 - mean_absolute_error: 26.8581 - val_loss: 266.9469 - val_mean_absolute_error: 14.7157
# Epoch 47/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1010.1304 - mean_absolute_error: 26.8619 - val_loss: 266.2029 - val_mean_absolute_error: 14.6923
# Epoch 48/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1009.8713 - mean_absolute_error: 26.8580 - val_loss: 268.1889 - val_mean_absolute_error: 14.7547
# Epoch 49/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1009.7618 - mean_absolute_error: 26.8549 - val_loss: 272.3294 - val_mean_absolute_error: 14.8839
# Epoch 50/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1009.9174 - mean_absolute_error: 26.8549 - val_loss: 278.0799 - val_mean_absolute_error: 15.0613
# Epoch 51/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1009.6934 - mean_absolute_error: 26.8613 - val_loss: 286.4087 - val_mean_absolute_error: 15.3144
# Epoch 52/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1010.7074 - mean_absolute_error: 26.8677 - val_loss: 284.9348 - val_mean_absolute_error: 15.2699
# Epoch 53/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1010.7753 - mean_absolute_error: 26.8800 - val_loss: 303.9526 - val_mean_absolute_error: 15.8583
# Epoch 54/100
# 7/7 [==============================] - 0s 8ms/step - loss: 980.2250 - mean_absolute_error: 26.3136 - val_loss: 278.1704 - val_mean_absolute_error: 15.0678
# Epoch 55/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1000.5273 - mean_absolute_error: 26.7324 - val_loss: 259.8533 - val_mean_absolute_error: 14.4940
# Epoch 56/100
# 7/7 [==============================] - 0s 8ms/step - loss: 970.7421 - mean_absolute_error: 26.3008 - val_loss: 546.6096 - val_mean_absolute_error: 22.3290
# Epoch 57/100
# 7/7 [==============================] - 0s 8ms/step - loss: 962.0400 - mean_absolute_error: 26.3354 - val_loss: 241.2351 - val_mean_absolute_error: 13.9012
# Epoch 58/100
# 7/7 [==============================] - 0s 8ms/step - loss: 892.8273 - mean_absolute_error: 25.1527 - val_loss: 455.8635 - val_mean_absolute_error: 20.2208
# Epoch 59/100
# 7/7 [==============================] - 0s 8ms/step - loss: 848.2651 - mean_absolute_error: 24.5441 - val_loss: 276.5287 - val_mean_absolute_error: 15.1372
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 796.5042 - mean_absolute_error: 23.8377 - val_loss: 420.0841 - val_mean_absolute_error: 19.4195
# Epoch 61/100
# 7/7 [==============================] - 0s 10ms/step - loss: 775.8034 - mean_absolute_error: 23.2434 - val_loss: 211.1512 - val_mean_absolute_error: 12.9881
# Epoch 62/100
# 7/7 [==============================] - 0s 9ms/step - loss: 775.4247 - mean_absolute_error: 23.5833 - val_loss: 194.5018 - val_mean_absolute_error: 12.3465
# Epoch 63/100
# 7/7 [==============================] - 0s 8ms/step - loss: 768.4341 - mean_absolute_error: 23.1809 - val_loss: 202.5606 - val_mean_absolute_error: 12.7179
# Epoch 64/100
# 7/7 [==============================] - 0s 8ms/step - loss: 723.9384 - mean_absolute_error: 22.5667 - val_loss: 233.2281 - val_mean_absolute_error: 13.8067
# Epoch 65/100
# 7/7 [==============================] - 0s 8ms/step - loss: 705.4669 - mean_absolute_error: 22.2916 - val_loss: 211.1046 - val_mean_absolute_error: 13.0611
# Epoch 66/100
# 7/7 [==============================] - 0s 8ms/step - loss: 664.2714 - mean_absolute_error: 21.6100 - val_loss: 271.7512 - val_mean_absolute_error: 15.1879
# Epoch 67/100
# 7/7 [==============================] - 0s 8ms/step - loss: 629.7103 - mean_absolute_error: 21.0307 - val_loss: 232.0221 - val_mean_absolute_error: 13.8442
# Epoch 68/100
# 7/7 [==============================] - 0s 8ms/step - loss: 611.4602 - mean_absolute_error: 20.7822 - val_loss: 180.9416 - val_mean_absolute_error: 11.9899
# Epoch 69/100
# 7/7 [==============================] - 0s 9ms/step - loss: 574.9564 - mean_absolute_error: 20.0454 - val_loss: 122.2253 - val_mean_absolute_error: 9.3945
# Epoch 70/100
# 7/7 [==============================] - 0s 8ms/step - loss: 552.3975 - mean_absolute_error: 19.6870 - val_loss: 125.2259 - val_mean_absolute_error: 9.5973
# Epoch 71/100
# 7/7 [==============================] - 0s 8ms/step - loss: 501.8188 - mean_absolute_error: 18.6157 - val_loss: 221.7173 - val_mean_absolute_error: 13.6015
# Epoch 72/100
# 7/7 [==============================] - 0s 8ms/step - loss: 482.7856 - mean_absolute_error: 18.4014 - val_loss: 216.3254 - val_mean_absolute_error: 13.4402
# Epoch 73/100
# 7/7 [==============================] - 0s 8ms/step - loss: 435.0926 - mean_absolute_error: 17.2950 - val_loss: 101.8813 - val_mean_absolute_error: 8.5212
# Epoch 74/100
# 7/7 [==============================] - 0s 8ms/step - loss: 393.2949 - mean_absolute_error: 16.2611 - val_loss: 109.5650 - val_mean_absolute_error: 8.9672
# Epoch 75/100
# 7/7 [==============================] - 0s 9ms/step - loss: 317.5188 - mean_absolute_error: 14.2049 - val_loss: 74.1138 - val_mean_absolute_error: 7.0544
# Epoch 76/100
# 7/7 [==============================] - 0s 9ms/step - loss: 272.3853 - mean_absolute_error: 13.0748 - val_loss: 64.1130 - val_mean_absolute_error: 6.4960
# Epoch 77/100
# 7/7 [==============================] - 0s 10ms/step - loss: 230.6886 - mean_absolute_error: 11.8636 - val_loss: 60.8921 - val_mean_absolute_error: 6.3404
# Epoch 78/100
# 7/7 [==============================] - 0s 8ms/step - loss: 187.8085 - mean_absolute_error: 10.5923 - val_loss: 54.8066 - val_mean_absolute_error: 6.0110
# Epoch 79/100
# 7/7 [==============================] - 0s 8ms/step - loss: 156.5588 - mean_absolute_error: 9.3871 - val_loss: 44.8440 - val_mean_absolute_error: 5.5042
# Epoch 80/100
# 7/7 [==============================] - 0s 8ms/step - loss: 129.4042 - mean_absolute_error: 8.2133 - val_loss: 32.2629 - val_mean_absolute_error: 4.8805
# Epoch 81/100
# 7/7 [==============================] - 0s 9ms/step - loss: 117.3672 - mean_absolute_error: 8.3466 - val_loss: 70.5786 - val_mean_absolute_error: 7.0254
# Epoch 82/100
# 7/7 [==============================] - 0s 8ms/step - loss: 109.6874 - mean_absolute_error: 8.3694 - val_loss: 50.2722 - val_mean_absolute_error: 5.9139
# Epoch 83/100
# 7/7 [==============================] - 0s 8ms/step - loss: 102.3687 - mean_absolute_error: 7.9140 - val_loss: 42.9638 - val_mean_absolute_error: 5.2993
# Epoch 84/100
# 7/7 [==============================] - 0s 8ms/step - loss: 92.8481 - mean_absolute_error: 8.0062 - val_loss: 50.9937 - val_mean_absolute_error: 5.6947
# Epoch 85/100
# 7/7 [==============================] - 0s 9ms/step - loss: 79.5922 - mean_absolute_error: 7.2305 - val_loss: 48.8516 - val_mean_absolute_error: 5.5529
# Epoch 86/100
# 7/7 [==============================] - 0s 9ms/step - loss: 69.4845 - mean_absolute_error: 6.5733 - val_loss: 89.8188 - val_mean_absolute_error: 7.7914
# Epoch 87/100
# 7/7 [==============================] - 0s 9ms/step - loss: 71.8967 - mean_absolute_error: 6.6886 - val_loss: 78.9512 - val_mean_absolute_error: 7.2316
# Epoch 88/100
# 7/7 [==============================] - 0s 9ms/step - loss: 54.4557 - mean_absolute_error: 5.6435 - val_loss: 84.9908 - val_mean_absolute_error: 7.5496
# Epoch 89/100
# 7/7 [==============================] - 0s 8ms/step - loss: 49.7978 - mean_absolute_error: 5.5152 - val_loss: 73.2238 - val_mean_absolute_error: 6.9008
# Epoch 90/100
# 7/7 [==============================] - 0s 8ms/step - loss: 43.5383 - mean_absolute_error: 5.0235 - val_loss: 71.6057 - val_mean_absolute_error: 6.7980
# Epoch 91/100
# 7/7 [==============================] - 0s 8ms/step - loss: 42.5658 - mean_absolute_error: 5.1786 - val_loss: 49.0393 - val_mean_absolute_error: 5.6749
# Epoch 92/100
# 7/7 [==============================] - 0s 8ms/step - loss: 34.9269 - mean_absolute_error: 4.4620 - val_loss: 48.8039 - val_mean_absolute_error: 5.6817
# Epoch 93/100
# 7/7 [==============================] - 0s 10ms/step - loss: 33.0255 - mean_absolute_error: 4.4485 - val_loss: 42.1988 - val_mean_absolute_error: 5.3048
# Epoch 94/100
# 7/7 [==============================] - 0s 8ms/step - loss: 31.4926 - mean_absolute_error: 4.2873 - val_loss: 41.3385 - val_mean_absolute_error: 5.2564
# Epoch 95/100
# 7/7 [==============================] - 0s 10ms/step - loss: 28.1376 - mean_absolute_error: 4.0579 - val_loss: 39.7599 - val_mean_absolute_error: 5.1402
# Epoch 96/100
# 7/7 [==============================] - 0s 9ms/step - loss: 27.3522 - mean_absolute_error: 4.0807 - val_loss: 35.3714 - val_mean_absolute_error: 4.8676
# Epoch 97/100
# 7/7 [==============================] - 0s 9ms/step - loss: 30.7379 - mean_absolute_error: 4.2217 - val_loss: 58.0158 - val_mean_absolute_error: 6.1782
# Epoch 98/100
# 7/7 [==============================] - 0s 8ms/step - loss: 32.3809 - mean_absolute_error: 4.6349 - val_loss: 136.2589 - val_mean_absolute_error: 10.2293
# Epoch 99/100
# 7/7 [==============================] - 0s 8ms/step - loss: 42.0762 - mean_absolute_error: 5.4548 - val_loss: 101.1186 - val_mean_absolute_error: 8.4565
# Epoch 100/100
# 7/7 [==============================] - 0s 8ms/step - loss: 31.4928 - mean_absolute_error: 4.6922 - val_loss: 49.7200 - val_mean_absolute_error: 5.7929

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 1s 4ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
